# %%
# coding: utf-8
"""
作成したDNPライブラリを使うためのコード
"""

from library.dnp import DNP, evaluation
from library.filer import Filer

# %% [markdown]
# ###ライブラリを使用するためのサンプル

# %%
dnp = DNP(inputpath="./files/edmunds/edmunds_corpus_edgelist_co.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
print dnp.list_topic_prob
dnp.show_topic(n=7)

eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()

# %% [markdown]
# ### Newman法によってクラス数を指定して，精度を記録していく．DNなし．修論概要用

# %%
# 記録用の配列
list_score = []
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_co.csv")
eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
for num in range(3, 21):
    dnp.calculation(low_freq=0.002, low_rate=0.6, n=num, flag_DN=False, flag_louvain=False)
    eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
    list_score.append([eva.dict_score["purity"], eva.dict_score["invpurity"], eva.dict_score["fvalue"]])
# 結果の保存
Filer.writecsv(list_score, "./files/clustering.csv")
# Out:
# クラスタ数:  3
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.9567e-03 -1.0035e+00  1e+00  3e-16  2e+00
#  1: -2.9570e-03 -1.3463e-02  1e-02  2e-16  2e-02
#  2: -2.9766e-03 -3.4433e-03  5e-04  1e-16  1e-03
#  3: -3.0032e-03 -3.0201e-03  2e-05  6e-17  1e-18
#  4: -3.0033e-03 -3.0035e-03  2e-07  8e-17  1e-18
#  5: -3.0033e-03 -3.0033e-03  2e-09  1e-16  8e-19
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.09 	CPU Time Elapsed = 0.01
# objFuncValue: -0.003003317 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2
# クラスタ数:  4
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.9415e-03 -1.0035e+00  1e+00  1e-16  3e+00
#  1: -2.9420e-03 -1.3503e-02  1e-02  1e-16  3e-02
#  2: -2.9692e-03 -3.4591e-03  5e-04  3e-17  1e-03
#  3: -2.9971e-03 -3.0181e-03  2e-05  1e-16  9e-06
#  4: -2.9975e-03 -2.9977e-03  3e-07  2e-16  9e-08
#  5: -2.9975e-03 -2.9975e-03  3e-09  1e-16  9e-10
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0029974593 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1998
# エラーデータ数:  2
# クラスタ数:  5
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.8785e-03 -1.0036e+00  1e+00  1e-16  3e+00
#  1: -2.8798e-03 -1.3587e-02  1e-02  6e-17  3e-02
#  2: -2.9415e-03 -3.4658e-03  5e-04  8e-17  1e-03
#  3: -2.9971e-03 -3.0338e-03  4e-05  8e-17  2e-05
#  4: -2.9990e-03 -3.0000e-03  1e-06  8e-17  1e-07
#  5: -2.9990e-03 -2.9990e-03  1e-08  6e-17  1e-09
#  6: -2.9990e-03 -2.9990e-03  1e-10  4e-17  1e-11
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0029990209 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2
# クラスタ数:  6
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.7022e-03 -1.0040e+00  1e+00  4e-16  3e+00
#  1: -2.7050e-03 -1.3970e-02  1e-02  1e-16  3e-02
#  2: -2.8429e-03 -3.7098e-03  9e-04  1e-16  2e-03
#  3: -2.9842e-03 -3.0791e-03  9e-05  7e-17  6e-05
#  4: -2.9987e-03 -3.0055e-03  7e-06  1e-16  8e-19
#  5: -2.9994e-03 -2.9998e-03  4e-07  9e-17  2e-18
#  6: -2.9994e-03 -2.9994e-03  5e-09  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9700e-03 -1.0051e+00  1e+00  7e-17  5e+00
#  1: -1.9734e-03 -1.5137e-02  1e-02  1e-16  6e-02
#  2: -2.1913e-03 -4.8481e-03  3e-03  4e-17  1e-02
#  3: -2.8095e-03 -3.7308e-03  9e-04  1e-16  3e-18
#  4: -2.9634e-03 -3.0925e-03  1e-04  4e-17  3e-18
#  5: -2.9957e-03 -3.0107e-03  2e-05  7e-17  2e-18
#  6: -2.9996e-03 -3.0023e-03  3e-06  7e-17  2e-18
#  7: -3.0002e-03 -3.0007e-03  5e-07  8e-17  2e-18
#  8: -3.0003e-03 -3.0004e-03  2e-07  8e-17  3e-18
#  9: -3.0004e-03 -3.0004e-03  4e-08  1e-16  2e-18
# 10: -3.0004e-03 -3.0004e-03  3e-09  6e-17  1e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0030003848 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2
# クラスタ数:  20
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9327e-03 -1.0052e+00  1e+00  2e-17  5e+00
#  1: -1.9362e-03 -1.5187e-02  1e-02  9e-17  6e-02
#  2: -2.1566e-03 -4.8989e-03  3e-03  8e-17  1e-02
#  3: -2.7983e-03 -3.7927e-03  1e-03  9e-17  2e-18
#  4: -2.9597e-03 -3.0958e-03  1e-04  4e-17  1e-18
#  5: -2.9953e-03 -3.0113e-03  2e-05  6e-17  1e-18
#  6: -2.9995e-03 -3.0025e-03  3e-06  4e-17  1e-18
#  7: -3.0002e-03 -3.0007e-03  5e-07  9e-17  1e-18
#  8: -3.0003e-03 -3.0004e-03  2e-07  2e-16  1e-18
#  9: -3.0004e-03 -3.0004e-03  5e-08  1e-16  2e-18
# 10: -3.0004e-03 -3.0004e-03  8e-09  4e-17  1e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.003000385 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2

# %% [markdown]
# ### Louvain法によりクラスタ数を指定せずに計算．DNなし．修論概要用

# %%
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_co.csv")
eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
print "============"
print "Newman"
print "============"
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=False)
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
print "============"
print "Louvain"
print "============"
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# ============
# Newman
# ============
# クラスタ数:  7
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.6112e-03 -1.0042e+00  1e+00  3e-17  3e+00
#  1: -2.6140e-03 -1.4157e-02  1e-02  8e-17  3e-02
#  2: -2.7667e-03 -3.8758e-03  1e-03  8e-17  3e-03
#  3: -2.9677e-03 -3.1185e-03  2e-04  6e-17  1e-04
#  4: -2.9974e-03 -3.0112e-03  1e-05  6e-17  3e-18
#  5: -2.9998e-03 -3.0009e-03  1e-06  1e-16  2e-18
#  6: -2.9998e-03 -2.9999e-03  5e-08  1e-16  1e-18
#  7: -2.9998e-03 -2.9998e-03  5e-10  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0029998451 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2
# ============
# Purity:  0.598098098098
# InversePurity:  0.695195195195
# F-value:  0.643001747878
# ============
# ============
# Louvain
# ============
# クラスタ数:  10
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.6412e-03 -1.0046e+00  1e+00  2e-16  3e+00
#  1: -2.6436e-03 -1.4547e-02  1e-02  1e-16  4e-02
#  2: -2.7798e-03 -4.2439e-03  1e-03  2e-16  5e-03
#  3: -2.9863e-03 -3.1891e-03  2e-04  1e-16  2e-18
#  4: -3.0044e-03 -3.0174e-03  1e-05  1e-16  2e-18
#  5: -3.0051e-03 -3.0056e-03  4e-07  1e-16  3e-18
#  6: -3.0052e-03 -3.0052e-03  4e-09  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0030051512 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1998
# エラーデータ数:  2
# ============
# Purity:  0.621621621622
# InversePurity:  0.676176176176
# F-value:  0.647752264413
# ============

# %% [markdown]
# ### Newman法でK=6指定で、トピックの内容とトピック分布を確認、paclic用

# %%
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_co.csv")
eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=6, flag_DN=False, flag_louvain=False)
print dnp.list_topic_prob
for i in range(0,6):
    dnp.show_topic(n=i)
# Out:
# クラスタ数:  6
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.7022e-03 -1.0040e+00  1e+00  4e-16  3e+00
#  1: -2.7050e-03 -1.3970e-02  1e-02  1e-16  3e-02
#  2: -2.8429e-03 -3.7098e-03  9e-04  1e-16  2e-03
#  3: -2.9842e-03 -3.0791e-03  9e-05  1e-16  6e-05
#  4: -2.9987e-03 -3.0055e-03  7e-06  1e-16  1e-18
#  5: -2.9994e-03 -2.9998e-03  4e-07  6e-17  2e-18
#  6: -2.9994e-03 -2.9994e-03  5e-09  8e-17  1e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0029994066 (feasible, MaxResidual = 0)
# [ 0.2577422   0.2237287   0.25355412  0.16754921  0.02703994  0.07038582]
# トピック:  0
# ==============
# 風呂 0.0261664671975
# 広い 0.0195845959715
# 気 0.015033303093
# 快適 0.0122325214203
# 大浴場 0.0119593061009
# 子供 0.0111780213815
# 無い 0.0106859321771
# 設備 0.00958470359704
# 狭い 0.00945194405068
# バス 0.00909168376993
# ==============
# トピック:  1
# ==============
# 対応 0.0413273823111
# フロント 0.0294799810208
# 感じ 0.0226953475842
# 予約 0.0208160105284
# いい 0.0204726881315
# チェックイン 0.016140905946
# スタッフ 0.0159861311279
# 女性 0.00983295790079
# 嬉しい 0.00943952520244
# 従業員 0.00939904520699
# ==============
# トピック:  2
# ==============
# 朝食 0.0407770395222
# 満足 0.0297869564376
# 大変 0.0279660703024
# サービス 0.0244486497561
# 食事 0.0230752867085
# 残念 0.0209935583521
# プラン 0.0178433826468
# 温泉 0.0119622054163
# 値段 0.0113117898912
# 無料 0.0111917444593
# ==============
# トピック:  3
# ==============
# よい 0.0416042680328
# 立地 0.0310752956232
# 駅 0.0209810188218
# 安い 0.0209168921576
# 料金 0.0202056139838
# 非常 0.0194961560992
# 便利 0.0181843174222
# 悪い 0.017658349664
# 近い 0.0170249284972
# 最高 0.0130884164618
# ==============
# トピック:  4
# ==============
# 別 0.0239223636746
# 入浴 0.0230577443044
# 浴室 0.0197998243705
# づらい 0.0177470209864
# 照明 0.0176785220222
# 鏡 0.0172099250147
# シャンプー 0.0163456300724
# 位置 0.0162422324115
# 表示 0.0158144380637
# 暗い 0.015380967407
# ==============
# トピック:  5
# ==============
# ない 0.0961513721096
# 他 0.0350943853634
# 人 0.0298667638157
# 用意 0.0216275593532
# 声 0.016706194748
# 接客 0.0140378466401
# 客 0.012383263536
# 客室 0.0110508429671
# エレベーター 0.0106142368082
# 廊下 0.00979326445538
# ==============

# %% [markdown]
# ### Edmundsのコーパスで精度の検証, paclic用, DNなし, louvain

# %%
dnp = DNP(inputpath="./files/edmunds/edmunds_corpus_edgelist_co.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
print dnp.list_topic_prob
dnp.show_topic(n=7)

eva = evaluation("./files/edmunds/list_id_label_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# クラスタ数:  8
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9257e-03 -1.0026e+00  1e+00  3e-17  3e+00
#  1: -1.9264e-03 -1.2635e-02  1e-02  2e-16  3e-02
#  2: -1.9751e-03 -2.6153e-03  6e-04  7e-17  2e-03
#  3: -2.0597e-03 -2.1275e-03  7e-05  1e-16  1e-18
#  4: -2.0633e-03 -2.0656e-03  2e-06  1e-16  1e-18
#  5: -2.0633e-03 -2.0634e-03  2e-08  1e-16  1e-18
#  6: -2.0633e-03 -2.0633e-03  2e-10  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.07 	CPU Time Elapsed = 0.01
# objFuncValue: -0.00206334 (feasible, MaxResidual = 0)
# [ 0.08948594  0.05337981  0.08080159  0.1829092   0.15395044  0.05367598
#   0.21004084  0.17575621]
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.376306620209
# InversePurity:  0.365853658537
# F-value:  0.371006526967
# ============

# %% [markdown]
# ### Edmundsのコーパスで精度の検証, paclic用, DNなし, Newman

# %%
dnp = DNP(inputpath="./files/edmunds/edmunds_corpus_edgelist_co.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
print dnp.list_topic_prob
#dnp.show_topic(n=7)

eva = evaluation("./files/edmunds/list_id_label_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# クラスタ数:  8
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9257e-03 -1.0026e+00  1e+00  3e-17  3e+00
#  1: -1.9264e-03 -1.2635e-02  1e-02  2e-16  3e-02
#  2: -1.9751e-03 -2.6153e-03  6e-04  7e-17  2e-03
#  3: -2.0597e-03 -2.1275e-03  7e-05  1e-16  1e-18
#  4: -2.0633e-03 -2.0656e-03  2e-06  1e-16  1e-18
#  5: -2.0633e-03 -2.0634e-03  2e-08  1e-16  1e-18
#  6: -2.0633e-03 -2.0633e-03  2e-10  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.00206334 (feasible, MaxResidual = 0)
# [ 0.08948594  0.05337981  0.08080159  0.1829092   0.15395044  0.05367598
#   0.21004084  0.17575621]
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.376306620209
# InversePurity:  0.365853658537
# F-value:  0.371006526967
# ============

# %% [markdown]
# ### Edmundsのコーパスで精度の検証, paclic用, DNなし, Newman, 3~21

# %%
for i in range(3,21):
    dnp = DNP(inputpath="./files/edmunds/edmunds_corpus_edgelist_co.csv")
    dnp.calculation(low_freq=0.002, low_rate=0.6, n=i, flag_DN=False, flag_louvain=False)
    #dnp.show_topic(n=7)

    eva = evaluation("./files/edmunds/list_id_label_sep.dump")
    eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
    eva.show_score()
# Out:
# クラスタ数:  3
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9389e-03 -1.0026e+00  1e+00  2e-16  2e+00
#  1: -1.9396e-03 -1.2573e-02  1e-02  2e-16  2e-02
#  2: -1.9825e-03 -2.5633e-03  6e-04  6e-17  1e-03
#  3: -2.0585e-03 -2.1201e-03  6e-05  3e-17  9e-19
#  4: -2.0601e-03 -2.0613e-03  1e-06  8e-17  7e-19
#  5: -2.0601e-03 -2.0601e-03  1e-08  6e-17  5e-19
#  6: -2.0601e-03 -2.0601e-03  1e-10  6e-17  6e-19
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020601154 (feasible, MaxResidual = 0)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.313588850174
# InversePurity:  0.604529616725
# F-value:  0.412961408009
# ============
# クラスタ数:  4
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.0458e-03 -1.0023e+00  1e+00  4e-16  3e+00
#  1: -2.0459e-03 -1.2255e-02  1e-02  2e-16  3e-02
#  2: -2.0515e-03 -2.3195e-03  3e-04  8e-17  7e-04
#  3: -2.0606e-03 -2.0683e-03  8e-06  1e-16  5e-06
#  4: -2.0607e-03 -2.0607e-03  8e-08  8e-17  5e-08
#  5: -2.0607e-03 -2.0607e-03  8e-10  1e-16  5e-10
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020606637 (feasible, MaxResidual = 0)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.306620209059
# InversePurity:  0.469512195122
# F-value:  0.370972598615
# ============
# クラスタ数:  5
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.9582e-03 -1.0024e+00  1e+00  2e-16  3e+00
#  1: -1.9589e-03 -1.2444e-02  1e-02  1e-16  3e-02
#  2: -1.9994e-03 -2.4389e-03  4e-04  8e-17  1e-03
#  3: -2.0557e-03 -2.0920e-03  4e-05  7e-17  2e-05
#  4: -2.0604e-03 -2.0628e-03  2e-06  1e-16  9e-19
#  5: -2.0605e-03 -2.0605e-03  3e-08  6e-17  8e-19
#  6: -2.0605e-03 -2.0605e-03  3e-10  1e-16  1e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020604579 (feasible, MaxResidual = 0)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.321428571429
# InversePurity:  0.478222996516
# F-value:  0.384453781513
# ============
# クラスタ数:  6
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.7671e-03 -1.0027e+00  1e+00  8e-17  3e+00
#  1: -1.7693e-03 -1.2717e-02  1e-02  1e-16  3e-02
#  2: -1.8871e-03 -2.6160e-03  7e-04  6e-17  2e-03
#  3: -2.0407e-03 -2.1221e-03  8e-05  7e-17  1e-18
#  4: -2.0593e-03 -2.0679e-03  9e-06  1e-16  1e-18
#  5: -2.0607e-03 -2.0614e-03  7e-07  1e-16  2e-18
#  6: -2.0608e-03 -2.0608e-03  2e-08  7e-17  2e-18
#  7: -2.0608e-03 -2.0608e-03  2e-10  7e-17  8e-19
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020607541 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020617693 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.325783972125
# InversePurity:  0.476480836237
# F-value:  0.386979007063
# ============
# クラスタ数:  19
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.3142e-03 -1.0035e+00  1e+00  4e-16  5e+00
#  1: -1.3158e-03 -1.3474e-02  1e-02  3e-16  6e-02
#  2: -1.4334e-03 -3.3889e-03  2e-03  2e-16  9e-03
#  3: -1.9234e-03 -2.7719e-03  8e-04  7e-17  3e-18
#  4: -2.0282e-03 -2.1509e-03  1e-04  2e-16  1e-18
#  5: -2.0574e-03 -2.0735e-03  2e-05  7e-17  2e-18
#  6: -2.0615e-03 -2.0633e-03  2e-06  1e-16  2e-18
#  7: -2.0618e-03 -2.0620e-03  2e-07  2e-16  1e-18
#  8: -2.0618e-03 -2.0618e-03  3e-08  6e-17  1e-18
#  9: -2.0618e-03 -2.0618e-03  2e-09  1e-16  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020617934 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.325783972125
# InversePurity:  0.476480836237
# F-value:  0.386979007063
# ============
# クラスタ数:  20
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -1.2836e-03 -1.0035e+00  1e+00  2e-16  5e+00
#  1: -1.2852e-03 -1.3512e-02  1e-02  2e-16  6e-02
#  2: -1.4057e-03 -3.4259e-03  2e-03  9e-17  9e-03
#  3: -1.9160e-03 -2.8331e-03  9e-04  7e-17  3e-18
#  4: -2.0236e-03 -2.1672e-03  1e-04  3e-17  1e-18
#  5: -2.0566e-03 -2.0754e-03  2e-05  1e-16  1e-18
#  6: -2.0614e-03 -2.0636e-03  2e-06  1e-16  1e-18
#  7: -2.0618e-03 -2.0620e-03  2e-07  8e-17  9e-19
#  8: -2.0618e-03 -2.0618e-03  3e-08  9e-17  8e-19
#  9: -2.0618e-03 -2.0618e-03  2e-09  1e-16  6e-19
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0020618061 (feasible, MaxResidual = 0)
# テストデータ数:  1148
# エラーデータ数:  0
# ============
# Purity:  0.326655052265
# InversePurity:  0.475609756098
# F-value:  0.387304361643
# ============

# %% [markdown]
# ### トピック確認用 paclic

# %%
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_co.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
#dnp.show_topic(n=7)

eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# クラスタ数:  10
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.6412e-03 -1.0046e+00  1e+00  2e-16  3e+00
#  1: -2.6436e-03 -1.4547e-02  1e-02  1e-16  4e-02
#  2: -2.7798e-03 -4.2439e-03  1e-03  2e-16  5e-03
#  3: -2.9863e-03 -3.1891e-03  2e-04  7e-17  3e-18
#  4: -3.0044e-03 -3.0174e-03  1e-05  2e-16  2e-18
#  5: -3.0051e-03 -3.0056e-03  4e-07  3e-17  2e-18
#  6: -3.0052e-03 -3.0052e-03  4e-09  4e-17  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0030051512 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1998
# エラーデータ数:  2
# ============
# Purity:  0.621621621622
# InversePurity:  0.676176176176
# F-value:  0.647752264413
# ============

# %%
dnp.list_topic_prob
# Out:
# array([ 0.2577422 ,  0.2237287 ,  0.25355412,  0.16754921,  0.02703994,
#         0.07038582])

# %%
print dnp.list_topic_prob
# Out:
# [  2.50072277e-01   2.16947520e-01   2.51624964e-01   1.64830397e-01
#    2.13313739e-02   6.93948936e-02   7.62067466e-03   2.28142099e-04
#    2.92683833e-06   1.57689140e-05   1.28045845e-05   1.79182568e-02]

# %% [markdown]
# ### window_graph(zhao参照)のグラフを用いた場合の精度

# %%
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_window3.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=20, flag_DN=False, flag_louvain=True)
#dnp.show_topic(n=7)

eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# クラスタ数:  9
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.9163e-03 -1.0040e+00  1e+00  2e-16  3e+00
#  1: -2.9174e-03 -1.3968e-02  1e-02  6e-17  4e-02
#  2: -2.9834e-03 -3.7862e-03  8e-04  8e-17  3e-03
#  3: -3.0725e-03 -3.1535e-03  8e-05  1e-16  1e-18
#  4: -3.0753e-03 -3.0774e-03  2e-06  1e-16  2e-18
#  5: -3.0753e-03 -3.0754e-03  2e-08  6e-17  1e-18
#  6: -3.0753e-03 -3.0753e-03  2e-10  4e-17  2e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0030753465 (feasible, MaxResidual = 0)
# テストデータ数:  1998
# エラーデータ数:  2
# ============
# Purity:  0.612612612613
# InversePurity:  0.636136136136
# F-value:  0.624152810125
# ============

# %%
dnp = DNP(inputpath="./files/rakuten_corpus/rakuten_corpus_edgelist_window5.csv")
dnp.calculation(low_freq=0.002, low_rate=0.6, n=0, flag_DN=False, flag_louvain=True)
#dnp.show_topic(n=7)

eva = evaluation("./files/rakuten_corpus/annotation/all_sep.dump")
eva.cal_f_measure(dnp.list_dict_word_prob, dnp.list_topic_prob)
eva.show_score()
# Out:
# クラスタ数:  8
#
# ------------------------- OpenOpt 0.5625 -------------------------
# problem: unnamed   type: QP
# solver: cvxopt_qp
#      pcost       dcost       gap    pres   dres
#  0: -2.8738e-03 -1.0039e+00  1e+00  2e-16  3e+00
#  1: -2.8753e-03 -1.3918e-02  1e-02  7e-17  4e-02
#  2: -2.9517e-03 -3.7774e-03  8e-04  1e-16  3e-03
#  3: -3.0406e-03 -3.1227e-03  8e-05  7e-17  2e-18
#  4: -3.0433e-03 -3.0454e-03  2e-06  6e-17  2e-18
#  5: -3.0433e-03 -3.0434e-03  2e-08  7e-17  2e-18
#  6: -3.0433e-03 -3.0433e-03  2e-10  5e-17  1e-18
# Optimal solution found.
# istop: 1000 (optimal)
# Solver:   Time Elapsed = 0.0 	CPU Time Elapsed = 0.0
# objFuncValue: -0.0030433395 (feasible, MaxResidual = 1.11022e-16)
# テストデータ数:  1997
# エラーデータ数:  3
# ============
# Purity:  0.608913370055
# InversePurity:  0.655483224837
# F-value:  0.631340674378
# ============
